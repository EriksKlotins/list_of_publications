# %%
import pandas as pd
import numpy as np

# %%
def collapse_ids(ids):
    if len(ids)>0:
        ids = sorted(ids)
        is_group = False
        result = [ids[0]]
        for i, id in enumerate(ids):
            if i==0:
                continue       
            if (id == ids[i-1]+1) & (not is_group):
                is_group=True
                result.append('-')
            if (is_group & (id != ids[i-1]+1)):
                is_group = False
                result.append(ids[i-1])
            
            if is_group & (len(ids) == i+1):
                result.append(ids[i])
                result.append(', ')
            if not is_group:
                result.append(', ')
                result.append(id)
        return '['+''.join(map(str,result)).strip(', ')+']'
    else:
        return ''



print(collapse_ids([101,1,2,3,999,5,6,99,100]))
print(collapse_ids([1,2,3]))
print(collapse_ids([1,24,35]))
print(collapse_ids([1,3]))
print(collapse_ids([]))
# Out:
# [1-3, 5-6, 99-101, 999]
# [1-3]
# [1, 24, 35]
# [1, 3]

# %%
# https://docs.google.com/spreadsheets/d/1XN2hxenZtmYpYkplkH6CIW3iypAPI27j/edit?gid=774440903#gid=774440903
sheet_id = "1XN2hxenZtmYpYkplkH6CIW3iypAPI27j"
sheet_name = "Sheet1" 

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
pubs = pd.read_csv(url).fillna(False).replace("x",True)
pubs.columns = [col.strip() for col in pubs.columns]

# %%
# first fix numbering into chronological order
# pubs = pubs.sort_values('Year')
pubs = pubs.sort_values([ 'Is journal', 'Is conference', 'Is workshop','Year'],ascending=[False, False, False, True])
pubs['ID'] = np.arange(1, len(pubs)+1)

# add another column for filtering
pubs['Total'] = True

# %%
filter_cols = [
    'Total',
    'Sole author',
    'First author', 'Most senior author',
    'With supervised doctoral student',
    'With supervised first or second cycle student',
    'With external collaboration partner', 
    'With domestic academic partner',
    'With international collaboration partner',
    'Publications during the last 5 years'
]
data_cols = [
    'Is journal', 
    'Is conference', 
    'Is workshop',
    'Monograph', 
    'Anthologies', 
    'Articles in anthologies with peer-review',
    'Popular science works',
    'Study material',
    'Is other'
]

# %%
def format_cell(values):
    # print(values)
    # print()
    return f"{str(len(values))} {collapse_ids(values)}"
    
    

result = []
for fc in filter_cols:
    row = []
    for dc in data_cols:
       
        cat_pubs = pubs[(pubs[dc] == True) & (pubs[fc] == True )]
        row.append(format_cell(cat_pubs.ID.values))
    result.append(row)


publications_list = pd.DataFrame(result, index = filter_cols, columns = data_cols)

# # merge empty cols
merge_cols = ['Monograph','Anthologies','Articles in anthologies with peer-review','Popular science works']
# publications_list.columns[ publications_list.sum() == 0]
if len(merge_cols) > 0:
    new_col = ', '.join(merge_cols)
    publications_list[new_col] = 0
    publications_list=  publications_list.drop(columns=merge_cols)

publications_list




# result
# Out:
#                                                                Is journal  \
# Total                                                           14 [1-14]
# Sole author                                                            0
# First author                                              7 [4-8, 10, 12]
# Most senior author                                                     0
# With supervised doctoral student                                       0
# With supervised first or second cycle student                          0
# With external collaboration partner                             3 [10-12]
# With domestic academic partner                                     1 [11]
# With international collaboration partner       8 [2-3, 6, 8-9, 11, 13-14]
# Publications during the last 5 years                             9 [6-14]
#
#                                                    Is conference Is workshop  \
# Total                                                  9 [15-23]   3 [24-26]
# Sole author                                                   0    2 [24-25]
# First author                                    5 [15-17, 21-22]   3 [24-26]
# Most senior author                                        1 [22]      1 [26]
# With supervised doctoral student                              0           0
# With supervised first or second cycle student                 0           0
# With external collaboration partner                       1 [23]          0
# With domestic academic partner                                0       1 [26]
# With international collaboration partner       4 [17-18, 20, 23]          0
# Publications during the last 5 years                   5 [19-23]      1 [26]
#
#                                               Study material       Is other  \
# Total                                                 1 [28]  4 [27, 29-31]
# Sole author                                               0              0
# First author                                          1 [28]         1 [27]
# Most senior author                                    1 [28]             0
# With supervised doctoral student                          0          1 [29]
# With supervised first or second cycle student             0              0
# With external collaboration partner                   1 [28]         1 [29]
# With domestic academic partner                            0          1 [30]
# With international collaboration partner                  0   3 [27, 30-31]
# Publications during the last 5 years                  1 [28]  4 [27, 29-31]
#
#                                                Monograph, Anthologies, Articles in anthologies with peer-review, Popular science works
# Total                                                                                          0
# Sole author                                                                                    0
# First author                                                                                   0
# Most senior author                                                                             0
# With supervised doctoral student                                                               0
# With supervised first or second cycle student                                                  0
# With external collaboration partner                                                            0
# With domestic academic partner                                                                 0
# With international collaboration partner                                                       0
# Publications during the last 5 years                                                           0

# %%
for dc in data_cols:
    cat_pubs = pubs[(pubs[dc] == True)]
    if len(cat_pubs)>0:
        print('\n'+dc) 
        for id, ref in cat_pubs[['ID', 'Ref']].values:
            print(f"[{id}]\t{ref}")
# Out:
# Is journal
# [1]	Unterkalmsteiner, M., Gorschek, T., Feldt, R., & Klotins, E. (2015). Assessing requirements engineering and software test alignment—Five case studies. Journal of systems and software, 109, 62-77.
# [2]	Unterkalmsteiner, M., Abrahamsson, P., Wang, X., Nguyen-Duc, A., Shah, S. Q., Bajwa, S. S., ... & Yague, A. (2016). Software startups–a research agenda. e-Informatica Software Engineering Journal, 10(1), 89-123.
# [3]	Tripathi, N., Klotins, E., Prikladnicki, R., Oivo, M., Pompermaier, L. B., Kudakacheril, A. S., ... & Gorschek, T. (2018). An anatomy of requirements engineering in software startups using multi-vocal literature and case survey. Journal of Systems and Software, 146, 130-151.
# [4]	Klotins, E., Unterkalmsteiner, M., & Gorschek, T. (2018). Software engineering antipatterns in start-ups. IEEE Software, 36(2), 118-126.
# [5]	Klotins, E., Unterkalmsteiner, M., & Gorschek, T. (2018). Software-intensive product engineering in start-ups: a taxonomy. IEEE Software, 35(4), 44-52.
# [6]	Klotins, E., Unterkalmsteiner, M., Chatzipetrou, P., Gorschek, T., Prikladnicki, R., Tripathi, N., & Pompermaier, L. (2019). A progression model of software engineering goals, challenges, and practices in start-ups. IEEE Transactions on Software Engineering.
# [7]	Klotins, E., Unterkalmsteiner, M., & Gorschek, T. (2019). Software engineering in start-up companies: An analysis of 88 experience reports. Empirical Software Engineering, 24(1), 68-102.
# [8]	Klotins, E., Unterkalmsteiner, M., Chatzipetrou, P., Gorschek, T., Prikladnicki, R., Tripathi, N., & Pompermaier, L. B. (2021). Use of Agile Practices in Start-up Companies. e-Informatica Software Engineering Journal, 15(1).
# [9]	Smite, D., Papatheocharous, E., Tkalich, A., Klotins, E., Moe, N. B., Buvik, M., Changes in Perceived Productivity of Software Engineers during COVID-19 Pandemic: The Voice of Evidence, (In review by Journal of Systems and Software)
# [10]	Klotins, E., Gorschek, T., Sundelin, K., & Falk, E.,  Towards Cost-benefit Evaluation for Continuous* Software Engineering Activities, (Empirical Software Engineering)
# [11]	Smite, D., Tkalich, A., Moe, N. B., Papatheocharous, E., Klotins, E., & Buvik, M. P. (2022). Changes in perceived productivity of software engineers during COVID-19 pandemic: The voice of evidence. Journal of Systems and Software, 186, 111197.
# [12]	Klotins, E., Gorschek, & Wilson, M. The Hierarchy of Costs and Benefits of Continuous Software Engineering, (IEEE Software)
# [13]	Smite, D., Moe, N. B., Klotins, E., & Gonzalez-Huerta, J. (2021). From Forced Working-From-Home to Working-From-Anywhere: Two Revolutions in Telework., (In review by Communications of ACM)
# [14]	Šmite, D., Klotins, E., & Moe, N. B. (2024). What Attracts Employees to Work Onsite in Times of Increased Remote Working? IEEE Software.
#
#
# Is conference
# [15]	Klotins, E., Unterkalmsteiner, M., & Gorschek, T. (2015, June). Software engineering knowledge areas in startup companies: a mapping study. In International Conference of Software Business (pp. 245-257). Springer, Cham.1.
# [16]	Klotins E., & Goswani P., Criteria for PhD student performance assessment in Software Engineering and Computer Science programs in Sweden, Lärarlärdom (2016)
# [17]	Klotins, E., Unterkalmsteiner, M., Chatzipetrou, P., Gorschek, T., Prikladnicki, R., Tripathi, N., & Pompermaier, L. (2018, May). Exploration of technical debt in start-ups. In 2018 IEEE/ACM 40th International Conference on Software Engineering: Software Engineering in Practice Track (ICSE-SEIP) (pp. 75-84). IEEE.
# [18]	Hyrynsalmi, S., Klotins, E., Unterkalmsteiner, M., Gorschek, T., Tripathi, N., Pompermaier, L. B., & Prikladnicki, R. (2018, October). What is a Minimum Viable (Video) Game?. In Conference on e-Business, e-Services and e-Society (pp. 217-231). Springer, Cham.
# [19]	Usman, M., Felderer, M., Unterkalmsteiner, M., Klotins, E., Mendez, D., & Alegroth, E. (2020, November). Compliance requirements in large-scale software development: An industrial case study. In International Conference on Product-Focused Software Process Improvement (pp. 385-401). Springer, Cham.
# [20]	Smite, D., Mikalsen, M., Moe, N. B., Stray, V., & Klotins, E. (2021, June). From Collaboration to Solitude and Back: Remote Pair Programming During COVID-19. In International Conference on Agile Software Development (pp. 3-18). Springer, Cham.
# [21]	Klotins, E., Gorschek, T. (2022). Continuous Software Engineering in the Wild. In: Mendez, D., Wimmer, M., Winkler, D., Biffl, S., Bergsmann, J. (eds) Software Quality: The Next Big Thing in Software Engineering and Quality. SWQD 2022. Lecture Notes in Business Information Processing, vol 439. Springer, Cham. https://doi.org/10.1007/978-3-031-04115-0_1
# [22]	Klotins, E., Talbert-Goldstein, E. (2023). Organizational Conflicts in the Adoption of Continuous Software Engineering. In: Stettina, C.J., Garbajosa, J., Kruchten, P. (eds) Agile Processes in Software Engineering and Extreme Programming. XP 2023. Lecture Notes in Business Information Processing, vol 475. Springer, Cham. https://doi.org/10.1007/978-3-031-33976-9_10
# [23]	Darja Smite, Anastasiia Tkalich, Nils Brede Moe, Panagiota Chatzipetrou, Eriks Klotins and Per Kristian Helland, "Dual Effects of Hybrid Working on Performance: More Work Hours or More Work Time", XP, 2024
#
# Is workshop
# [24]	Klotins, E. (2017, May). Using the case survey method to explore engineering practices in software start-ups. In 2017 IEEE/ACM 1st International Workshop on Software Engineering for Startups (SoftStart) (pp. 24-26). IEEE.
# [25]	Klotins, E. (2018). Software start-ups through an empirical lens: are start-ups snowflakes?. In 1st International Workshop on Software-Intensive Business: Start-Ups, Ecosystems and Platforms, SiBW 2018, Espoo, Finland, 3 December 2018. CEUR-WS.
# [26]	Klotins, Eriks, and Einav Peretz-Andersson. "The unified perspective of digital transformation and continuous software engineering." Proceedings of the 5th International Workshop on Software-intensive Business: Towards Sustainable Software Business. 2022.
#
# Study material
# [28]	Klotins, E., Frattini, J., & Nordström, K., Teaching materials for Basic System Verification Course, (Lecture slides, videos, notes, assignments, and other supporting material) (2019-2021) Available upon request
#
# Is other
# [27]	Klotins, E., Boeva, V., Wnuk, K., Unterkalmsteiner, M., Gorschek, T., Jansen, S. . A collaborative method for identification and prioritization of data sources in MDRE. (In review by Journal of Systems and Software)
# [29]	Bhuwan Paudel, Javier Gonzalez-Huerta, Ehsan Zabardast and Eriks Klotins "Towards Measuring the Impact of Technical Debt on Lead Time: An Industrial Case Study" (in review by SEAA)
# [30]	Panagiota Chatzipetrou, Darja Smite, Anastasiia Tkalich, Nils Brede Moe and Eriks Klotins "Interest in Working Remotely: Is Gender a Factor?" (in review by SEAA)
# [31]	Anastasiia Tkalich, Eriks Klotins, Tor Sporsem, Viktoria Stray, Nils Brede Moe, Astri Barbala "User Feedback in Continuous Software Engineering: Revealing the State-of-Practice", 2024, in major revision by Empirical Software Engineering
